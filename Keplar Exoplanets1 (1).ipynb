# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\91773\OneDrive\Desktop\Djs Nova\exoplanets.csv')
df.head()
# Out:
#       kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2  10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  ...  \
# 0      1.000              0              0              0              0  ...
# 1      0.969              0              0              0              0  ...
# 2      0.000              0              0              0              0  ...
# 3      0.000              0              1              0              0  ...
# 4      1.000              0              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kepid              9564 non-null   int64
#  1   kepoi_name         9564 non-null   object
#  2   kepler_name        2359 non-null   object
#  3   koi_disposition    9564 non-null   object
#  4   koi_pdisposition   9564 non-null   object
#  5   koi_score          8054 non-null   float64
#  6   koi_fpflag_nt      9564 non-null   int64
#  7   koi_fpflag_ss      9564 non-null   int64
#  8   koi_fpflag_co      9564 non-null   int64
#  9   koi_fpflag_ec      9564 non-null   int64
#  10  koi_period         9564 non-null   float64
#  11  koi_period_err1    9110 non-null   float64
#  12  koi_period_err2    9110 non-null   float64
#  13  koi_time0bk        9564 non-null   float64
#  14  koi_time0bk_err1   9110 non-null   float64
#  15  koi_time0bk_err2   9110 non-null   float64
# ...

# %%
df.describe()
# Out:
#               kepid    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# count  9.564000e+03  8054.000000    9564.000000    9564.000000    9564.000000
# mean   7.690628e+06     0.480829       0.208595       0.232748       0.197512
# std    2.653459e+06     0.476928       4.767290       0.422605       0.398142
# min    7.574500e+05     0.000000       0.000000       0.000000       0.000000
# 25%    5.556034e+06     0.000000       0.000000       0.000000       0.000000
# 50%    7.906892e+06     0.334000       0.000000       0.000000       0.000000
# 75%    9.873066e+06     0.998000       0.000000       0.000000       0.000000
# max    1.293514e+07     1.000000     465.000000       1.000000       1.000000
#
#        koi_fpflag_ec     koi_period  koi_period_err1  koi_period_err2  \
# count    9564.000000    9564.000000      9110.000000      9110.000000
# mean        0.120033      75.671358         0.002148        -0.002148
# ...

# %%
df.shape
# Out:
# (9564, 49)

# %%
nan_columns = df.isnull().sum(axis = 0)
nan_columns
# Out:
# kepid                   0
# kepoi_name              0
# kepler_name          7205
# koi_disposition         0
# koi_pdisposition        0
# koi_score            1510
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_period              0
# koi_period_err1       454
# koi_period_err2       454
# koi_time0bk             0
# koi_time0bk_err1      454
# koi_time0bk_err2      454
# koi_impact            363
# koi_impact_err1       454
# koi_impact_err2       454
# koi_duration            0
# koi_duration_err1     454
# koi_duration_err2     454
# koi_depth             363
# koi_depth_err1        454
# koi_depth_err2        454
# koi_prad              363
# koi_prad_err1         363
# koi_prad_err2         363
# koi_teq               363
# koi_teq_err1         9564
# koi_teq_err2         9564
# koi_insol             321
# koi_insol_err1        321
# koi_insol_err2        321
# koi_model_snr         363
# ...

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sorted_vals = {k: v for k, v in sorted(nan_columns.items(), key=lambda item: item[1])}
sorted_vals
# Out:
# {'kepid': 0,
#  'kepoi_name': 0,
#  'koi_disposition': 0,
#  'koi_pdisposition': 0,
#  'koi_fpflag_nt': 0,
#  'koi_fpflag_ss': 0,
#  'koi_fpflag_co': 0,
#  'koi_fpflag_ec': 0,
#  'koi_period': 0,
#  'koi_time0bk': 0,
#  'koi_duration': 0,
#  'ra': 0,
#  'dec': 0,
#  'koi_kepmag': 1,
#  'koi_insol': 321,
#  'koi_insol_err1': 321,
#  'koi_insol_err2': 321,
#  'koi_tce_plnt_num': 346,
#  'koi_tce_delivname': 346,
#  'koi_impact': 363,
#  'koi_depth': 363,
#  'koi_prad': 363,
#  'koi_prad_err1': 363,
#  'koi_prad_err2': 363,
#  'koi_teq': 363,
#  'koi_model_snr': 363,
#  'koi_steff': 363,
#  'koi_slogg': 363,
#  'koi_srad': 363,
#  'koi_period_err1': 454,
#  'koi_period_err2': 454,
#  'koi_time0bk_err1': 454,
#  'koi_time0bk_err2': 454,
#  'koi_impact_err1': 454,
#  'koi_impact_err2': 454,
#  'koi_duration_err1': 454,
#  'koi_duration_err2': 454,
#  'koi_depth_err1': 454,
#  'koi_depth_err2': 454,
#  'koi_steff_err1': 468,
#  'koi_slogg_err1': 468,
#  'koi_slogg_err2': 468,
# ...

# %%
df = df.drop(columns=["kepler_name","koi_teq_err1","koi_teq_err2"])

# %%
df = df.dropna()
df = df.reset_index(drop=True)
df.shape
# Out:
# (7803, 46)

# %%
df["koi_fpflag_nt"].value_counts()
# Out:
# 0      7026
# 1       776
# 465       1
# Name: koi_fpflag_nt, dtype: int64

# %%
df = df[df["koi_fpflag_nt"] <= 1]
df["koi_fpflag_nt"].value_counts()
# Out:
# 0    7026
# 1     776
# Name: koi_fpflag_nt, dtype: int64

# %%
df["koi_disposition"].value_counts()
# Out:
# FALSE POSITIVE    3735
# CONFIRMED         2331
# CANDIDATE         1736
# Name: koi_disposition, dtype: int64

# %%
sns.countplot(df['koi_disposition'],palette='winter_r')
# Out:
# C:\Users\91773\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='koi_disposition', ylabel='count'>

# %%
def disposition_encode(x):
    if x == "FALSE POSITIVE":
        return -1
    if x == "CANDIDATE":
        return 0
    if x == "CONFIRMED":
        return 1
df["koi_disposition"] = df["koi_disposition"].apply(lambda x: disposition_encode(x))

df["koi_disposition"].value_counts()
# Out:
# -1    3735
#  1    2331
#  0    1736
# Name: koi_disposition, dtype: int64

# %%
df["koi_pdisposition"].value_counts()
# Out:
# CANDIDATE         4061
# FALSE POSITIVE    3741
# Name: koi_pdisposition, dtype: int64

# %%
sns.countplot(df['koi_pdisposition'],palette='winter_r')
# Out:
# C:\Users\91773\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='koi_pdisposition', ylabel='count'>

# %%
df["koi_pdisposition"] = df["koi_pdisposition"].apply(lambda x : 1 if x == "CANDIDATE" else -1)
df["koi_pdisposition"].value_counts()
# Out:
#  1    4061
# -1    3741
# Name: koi_pdisposition, dtype: int64

# %%
import matplotlib.pyplot as plt

Candidate = df[df.koi_pdisposition == 1]
FP = df[df.koi_pdisposition == -1]

raf, decf = FP.ra, FP.dec
rac, decc = Candidate.ra, Candidate.dec

fig = plt.figure(figsize=(8,8))

plt.scatter(raf, decf, s=4, label='False Positive')
plt.scatter(rac, decc, s=4, label="Candidates")

plt.xlabel("Right Ascension")
plt.ylabel("Declination")

plt.legend()

# %%
Candidate = df[df.koi_pdisposition == 1]

# %%
transit_prop=['koi_duration','koi_depth','koi_period']

target = [i for i in transit_prop]
plt.figure(figsize=(12,10))
for n,i in enumerate(target):
    plot=plt.subplot(3,3,n+1)
    sns.histplot(Candidate[i],color='green',bins=10)
    plt.title(f'{i.title()}',weight='bold')
    plt.tight_layout()

# %%
sns.scatterplot(data=df, x='koi_depth', y='koi_duration', hue=Candidate['koi_pdisposition'], palette='viridis')
plt.show()

# %%
c = df[df.koi_disposition == 1]

# %%
sns.displot(df['koi_teq'],color='blue',bins=20)

# %%
sns.barplot(df['koi_prad'],color='yellow')
# Out:
# C:\Users\91773\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='koi_prad'>

# %%
df.columns
# Out:
# Index(['kepid', 'kepoi_name', 'koi_disposition', 'koi_pdisposition',
#        'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_tce_delivname', 'koi_steff',
#        'koi_steff_err1', 'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1',
#        'koi_slogg_err2', 'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra',
#        'dec', 'koi_kepmag'],
#       dtype='object')

# %%
df.drop(columns=['kepid','kepoi_name','koi_insol','koi_insol_err1', 'koi_insol_err2','koi_slogg','koi_slogg_err1', 'koi_slogg_err2',],inplace=True)

# %%
df.shape
# Out:
# (7802, 38)

# %%
df1 = df[['koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
          'koi_fpflag_co', 'koi_fpflag_ec',
          'koi_period', 'koi_time0bk', 'koi_duration', 'koi_prad', 'koi_teq',
          'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_srad']]

# %%
plt.subplots(figsize=(20,20))
sns.heatmap(df1.corr(), square=True,annot=True)
plt.show()
